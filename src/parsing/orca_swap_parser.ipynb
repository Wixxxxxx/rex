# %%
# %pip install solders solana base58 anchorpy

# %%
import requests
import pandas as pd
import numpy as np
import json
import time
import datetime
from anchorpy import Idl, Program, Provider
from base58 import b58decode
from solders.pubkey import Pubkey
from solana.rpc.async_api import AsyncClient

from pprint import pprint
import concurrent.futures

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
WHIRLPOOL_PROGRAM_ID = "whirLbMiicVdio4qvUfM5KAg6Ct8VwpYzGff3uctyCc"
WHIRLPOOL_ADDRESS = "9tXiuRRw7kbejLhZXtxDxYs2REe43uH2e7k1kocgdM9B"
SWAP_METHODS = {"swap", "swap_v2", "two_hop_swap", "two_hop_swap_v2"}

HELIUS_API_KEY='8a9369ef-bac5-4468-a662-f3d45d032b1d'

# %%
def fetch_account_balance(token_vault_address: str):

  url = f"https://mainnet.helius-rpc.com/?api-key={HELIUS_API_KEY}"

  payload = {
      "jsonrpc": "2.0",
      "id": 1,
      "method": "getTokenAccountBalance",
      "params": [token_vault_address]
  }

  headers = {
      "accept": "application/json",
      "content-type": "application/json"
    }

  response = requests.post(url, json=payload, headers=headers)
  response_json = response.json()
  return response_json


def fetch_account_balance_parallel(token_vault_addresses: list[str]):
  balances = {}
  with concurrent.futures.ThreadPoolExecutor(max_workers=2) as executor:
    futures = {executor.submit(fetch_account_balance, addr): addr for addr in token_vault_addresses}

    for future in concurrent.futures.as_completed(futures):
      balances[futures[future]] = {
          'balance': future.result()['result']['value']['uiAmount'],
          'slot': future.result()['result']['context']['slot']
          }

  return balances


def fetch_signatures_for_address(address: str, limit: int=1000, before=None):
  url = f"https://mainnet.helius-rpc.com/?api-key={HELIUS_API_KEY}"

  params = {
      "limit": limit,
      }

  if before:
    params["before"] = before

  payload = {
      "jsonrpc": "2.0",
      "id": 1,
      "method": "getSignaturesForAddress",
      "params": [f"{address}", params]
      }

  headers = {
      "accept": "application/json",
      "content-type": "application/json"
    }

  response = requests.post(url, json=payload, headers=headers)
  response_json = response.json()
  return response_json


def fetch_signature_hist_from_address(address: str, lookback: int=14, before=None):
  current_time = time.time()
  cutoff_time = current_time - lookback * 24 * 60 * 60

  before = None if not before else before
  txs = {"slot": [], "block_time": [], "tx_signature": []}
  attempts = 0

  while True:
    if not before:
      print("Called API with no signature")
      response = fetch_signatures_for_address(address)
    else:
      print(f"Called API with signature {before}")
      response = fetch_signatures_for_address(address, before=before)


    result = response.get('result', None)

    if not result:
      print("No results returned. Retrying with delay...")
      time.sleep(3)
      attempts += 1
      if attempts > 0:
          continue

    attempts = 0

    batch = result

    for tx in batch:
      if tx["err"]:
        continue
      txs["slot"].append(tx["slot"])
      txs["block_time"].append(tx["blockTime"])
      txs["tx_signature"].append(tx["signature"])

    print('last observed block time:')
    oldest_time = min([tx["blockTime"] for tx in batch if tx.get("blockTime")])
    oldest_time_ui = datetime.datetime.fromtimestamp(oldest_time).strftime('%Y-%m-%d %H:%M:%S')
    print(f"{oldest_time_ui}")

    if oldest_time < cutoff_time:
      print("Desired block time reached!")
      break

    print('last observed signature:')
    before = result[-1]['signature']
    print(f"{before}")
    time.sleep(1)

  return pd.DataFrame(txs)


def fetch_raw_transaction(signature: str):
    url = f"https://mainnet.helius-rpc.com/?api-key={HELIUS_API_KEY}"
    payload = {
        "jsonrpc": "2.0",
        "id": 1,
        "method": "getTransaction",
        "params": [
            signature,
            {
                "encoding": "jsonParsed",
                "commitment": "finalized",
                "maxSupportedTransactionVersion": 0
            }
        ]
    }
    headers = {"accept": "application/json", "content-type": "application/json"}

    try:
        response = requests.post(url, json=payload, headers=headers)
        response.raise_for_status()  # Raise an error for HTTP 4xx/5xx
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Request failed: {e}")
        return None
    except ValueError:
        print("Invalid JSON in response.")
        return None


def setup_program(idl_file: str, program_pubkey: str="whirLbMiicVdio4qvUfM5KAg6Ct8VwpYzGff3uctyCc"):
  idl = Idl.from_json(open(idl_file).read())
  client = AsyncClient("https://api.mainnet-beta.solana.com")
  provider = Provider(client, None)
  program = Program(idl, Pubkey.from_string(program_pubkey), provider)
  return program


def decode_instruction(data_b58: str, program):
    data = b58decode(data_b58)
    try:
        ix = program.coder.instruction.parse(data)
        return ix.name
    except KeyError:
        return None


def get_pre_post_balances(tx_res, token_mint_a, token_mint_b, pool_address):
  tx_pre_post_balances = {
      'pre_balance_a': 0.0,
      'pre_balance_b': 0.0,
      'post_balance_a': 0.0,
      'post_balance_b': 0.0,
      'decimals_a': 0,
      'decimals_b': 0
  }


  meta = tx_res.get('result', {}).get('meta', {})
  pre_token_balances = meta.get('preTokenBalances', [])
  post_token_balances = meta.get('postTokenBalances', [])

  for bal in pre_token_balances:
    if bal.get('owner') == pool_address:
      mint = bal.get('mint')
      token = bal.get('uiTokenAmount', {})
      if mint == token_mint_a:
        tx_pre_post_balances['pre_balance_a'] = token.get('uiAmount', 0.0) or 0.0
        tx_pre_post_balances['decimals_a'] = token.get('decimals', 0) or 0
      elif mint == token_mint_b:
        tx_pre_post_balances['pre_balance_b'] = token.get('uiAmount', 0.0) or 0.0
        tx_pre_post_balances['decimals_b'] = token.get('decimals', 0) or 0


  for bal in post_token_balances:
    if bal['owner'] == pool_address:
      mint = bal.get('mint')
      token = bal.get('uiTokenAmount', {})
      if bal['mint'] == token_mint_a:
        tx_pre_post_balances['post_balance_a'] = token.get('uiAmount', 0.0) or 0.0
        tx_pre_post_balances['decimals_a'] = token.get('decimals', 0) or 0
      elif bal['mint'] == token_mint_b:
        tx_pre_post_balances['post_balance_b'] = token.get('uiAmount', 0.0) or 0.0
        tx_pre_post_balances['decimals_b'] = token.get('decimals', 0) or 0


  return tx_pre_post_balances


def get_swap_events_inner(res, pool_address, token_vault_a, token_vault_b, program):
  swap_events = []
  num_swaps = 0
  swap = {}
  vaultA_detected = False
  vaultB_detected = False

  if not res.get('result', None):
    return swap_events, num_swaps

  for inner in res['result']['meta']['innerInstructions']:
    ixs = inner["instructions"]

    for idx, ix in enumerate(ixs):
      program_id = ix.get('programId', None)
      data = ix.get('data', None)
      accounts = ix.get('accounts', None)

      # detect swap
      if program_id == WHIRLPOOL_PROGRAM_ID and accounts and data:
        ix_call = decode_instruction(data, program)

        if pool_address in accounts and ix_call is not None and ix_call in SWAP_METHODS:
          num_swaps += 1

          swap = {}
          vaultA_detected = False
          vaultB_detected = False

          # if swap detected loop through next inner instructions
          for next_ix in ixs[idx+1: ]:
            parsed = next_ix.get('parsed', None)

            if next_ix.get('programId') != "TokenkegQfeZyiNwAJbNbGKPFXCWuBvf9Ss623VQ5DA" or not parsed:
              continue

            info = parsed.get('info', None)
            src, dst = info.get('source'), info.get('destination')

            if 'tokenAmount' in info:
              amount = int(info['tokenAmount']['amount'])
            elif 'amount' in info:
              amount = int(info['amount'])

            if not src or not dst:
              continue

            if token_vault_a in [src, dst]:
                vaultA_detected = True
                swap['token_amount_a'] = amount
            elif token_vault_b in [src, dst]:
                vaultB_detected = True
                swap['token_amount_b'] = amount

            if vaultA_detected and vaultB_detected:
                swap_events.append(swap)
                break

  return swap_events, num_swaps


def get_swap_events_outer(res, pool_address, token_vault_a, token_vault_b, program):
  swap_events = []
  num_swaps = 0
  swap = {}
  vaultA_detected = False
  vaultB_detected = False

  if not res.get('result', None):
    return swap_events, num_swaps

  for idx, ix in enumerate(res['result']['transaction']['message']['instructions']):
    program_id = ix.get('programId', None)
    data = ix.get('data', None)
    accounts = ix.get('accounts', None)

    if program_id == WHIRLPOOL_PROGRAM_ID and accounts and data:
      ix_call = decode_instruction(data, program)

      if pool_address in accounts and ix_call is not None and ix_call in SWAP_METHODS:
        num_swaps += 1
        for inner_ix in res['result']['meta']['innerInstructions']:
          if inner_ix['index'] != idx:
            continue

          swap = {}
          vaultA_detected = False
          vaultB_detected = False

          for transfer in inner_ix['instructions']:

            parsed = transfer.get('parsed', None)

            if transfer.get('programId') != "TokenkegQfeZyiNwAJbNbGKPFXCWuBvf9Ss623VQ5DA" or not parsed:
              continue

            info = parsed.get('info', None)
            src, dst = info.get('source'), info.get('destination')

            if 'tokenAmount' in info:
              amount = int(info['tokenAmount']['amount'])
            elif 'amount' in info:
              amount = int(info['amount'])

            if not src or not dst:
              continue

            if token_vault_a in [src, dst]:
                vaultA_detected = True
                swap['token_amount_a'] = amount
            elif token_vault_b in [src, dst]:
                vaultB_detected = True
                swap['token_amount_b'] = amount

            if vaultA_detected and vaultB_detected:
                swap_events.append(swap)
                break

  return swap_events, num_swaps

# %%
def create_dataset_for_pool(pool_address: str, token_mint_a: str, token_mint_b: str, token_vault_a: str, token_vault_b: str, program_idl: str="/content/drive/MyDrive/colosseum_hackathon/parsing_code/whirlpool.json", lookback: int=14, before=None):
  txs_df = fetch_signature_hist_from_address(pool_address, lookback, before)

  # setup df
  txs_df['token_mint_a'] = token_mint_a
  txs_df['token_mint_b'] = token_mint_b
  txs_df['token_vault_a'] = token_vault_a
  txs_df['token_vault_b'] = token_vault_b

  txs_df['num_swaps'] = 0
  txs_df['token_amount_a'] = 0
  txs_df['token_amount_b'] = 0

  txs_df['pre_balance_a'] = 0.0
  txs_df['pre_balance_b'] = 0.0
  txs_df['post_balance_a'] = 0.0
  txs_df['post_balance_b'] = 0.0

  txs_df['decimals_a'] = 0
  txs_df['decimals_b'] = 0

  batch_num = 0

  # setup program from json to decode transactions
  program = setup_program(program_idl)

  print("Transaction collection complete :)")
  print(f"Total transactions: {txs_df.shape[0]}")

  for idx, row in txs_df.iterrows():
    res = fetch_raw_transaction(row['tx_signature'])

    if not res:
      print(f"❌ Failed to fetch transaction {idx}")
      continue

    # fetch swap amounts
    swap_events_inner, num_swaps_inner = get_swap_events_inner(res, pool_address, row['token_vault_a'], row['token_vault_b'], program)
    swap_events_outer, num_swaps_outer = get_swap_events_outer(res, pool_address, row['token_vault_a'], row['token_vault_b'], program)

    if swap_events_inner:
      token_amount_a = sum([int(swap['token_amount_a']) for swap in swap_events_inner])
      token_amount_b = sum([int(swap['token_amount_b']) for swap in swap_events_inner])

      txs_df.loc[idx, 'token_amount_a'] += token_amount_a
      txs_df.loc[idx, 'token_amount_b'] += token_amount_b
      txs_df.loc[idx, 'num_swaps'] += num_swaps_inner

    if swap_events_outer:
      token_amount_a = sum([int(swap['token_amount_a']) for swap in swap_events_outer])
      token_amount_b = sum([int(swap['token_amount_b']) for swap in swap_events_outer])

      txs_df.loc[idx, 'token_amount_a'] += token_amount_a
      txs_df.loc[idx, 'token_amount_b'] += token_amount_b
      txs_df.loc[idx, 'num_swaps'] += num_swaps_outer


    # get pre and post token balances
    pre_post_balances = get_pre_post_balances(res, row['token_mint_a'], row['token_mint_b'], pool_address)
    if pre_post_balances:
      txs_df.loc[idx, 'pre_balance_a'] = float(pre_post_balances['pre_balance_a'])
      txs_df.loc[idx, 'pre_balance_b'] = float(pre_post_balances['pre_balance_b'])
      txs_df.loc[idx, 'post_balance_a'] = float(pre_post_balances['post_balance_a'])
      txs_df.loc[idx, 'post_balance_b'] = float(pre_post_balances['post_balance_b'])
      txs_df.loc[idx, 'decimals_a'] = int(pre_post_balances['decimals_a'])
      txs_df.loc[idx, 'decimals_b'] = int(pre_post_balances['decimals_b'])

    print(f"Processed transaction {idx}")

    if (idx + 1) % 5000 == 0:
      path = f"/content/drive/MyDrive/colosseum_hackathon/datasets/pyusd_usdc_pool/pyusd_usdc_batch_{batch_num}.csv"
      txs_df.iloc[:idx+1].to_csv(path, index=False)
      print(f"✅ Saved progress to {path}")
      batch_num += 1

  print("Transaction processing complete :)")

  return txs_df

# %%
txs_df = create_dataset_for_pool(
    pool_address=WHIRLPOOL_ADDRESS,
    token_mint_a="2b1kV6DkPAnxd5ixfnxCpjxmKwqjjaYmCZfHsFu24GXo",
    token_mint_b="EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v",
    token_vault_a="EeF6oBy6AQiBJoRx5xiRNxa6cmpQE3ayVagj28QFZuyg",
    token_vault_b="MvB8poDgpDPbRgx8MXeb7EPEsawGuiBTqpkpM9exeLi",
    program_idl="/content/drive/MyDrive/colosseum_hackathon/parsing_code/whirlpool.json",
    lookback=60,
    before="4K7APXX7UvBCUvyVi7AJ4Cgqu1H7T2pb2Vf9cCAR1boBR493WHHZUgzicswLSTzRi2dA9aayWk2CVo8tbbaAbZCB"
    )
# Out:
# Streaming output truncated to the last 5000 lines.
# Processed transaction 45057
# Processed transaction 45058
# Processed transaction 45059
# Processed transaction 45060
# Processed transaction 45061
# Processed transaction 45062
# Processed transaction 45063
# Processed transaction 45064
# Processed transaction 45065
# Processed transaction 45066
# Processed transaction 45067
# Processed transaction 45068
# Processed transaction 45069
# Processed transaction 45070
# Processed transaction 45071
# Processed transaction 45072
# Processed transaction 45073
# Processed transaction 45074
# Processed transaction 45075
# Processed transaction 45076
# Processed transaction 45077
# Processed transaction 45078
# Processed transaction 45079
# Processed transaction 45080
# Processed transaction 45081
# Processed transaction 45082
# Processed transaction 45083
# Processed transaction 45084
# Processed transaction 45085
# Processed transaction 45086
# Processed transaction 45087
# Processed transaction 45088
# Processed transaction 45089
# Processed transaction 45090
# Processed transaction 45091
# Processed transaction 45092
# Processed transaction 45093
# Processed transaction 45094
# Processed transaction 45095
# Processed transaction 45096
# Processed transaction 45097
# Processed transaction 45098
# Processed transaction 45099
# Processed transaction 45100
# Processed transaction 45101
# Processed transaction 45102
# Processed transaction 45103
# Processed transaction 45104
# Processed transaction 45105
# Processed transaction 45106
# Processed transaction 45107
# Processed transaction 45108
# Processed transaction 45109
# Processed transaction 45110
# Processed transaction 45111
# Processed transaction 45112
# Processed transaction 45113
# Processed transaction 45114
# Processed transaction 45115
# Processed transaction 45116
# Processed transaction 45117
# Processed transaction 45118
# Processed transaction 45119
# Processed transaction 45120
# Processed transaction 45121
# Processed transaction 45122
# Processed transaction 45123
# Processed transaction 45124
# Processed transaction 45125
# Processed transaction 45126
# Processed transaction 45127
# Processed transaction 45128
# Processed transaction 45129
# Processed transaction 45130
# Processed transaction 45131
# Processed transaction 45132
# Processed transaction 45133
# Processed transaction 45134
# Processed transaction 45135
# Processed transaction 45136
# Processed transaction 45137
# Processed transaction 45138
# Processed transaction 45139
# Processed transaction 45140
# Processed transaction 45141
# Processed transaction 45142
# Processed transaction 45143
# Processed transaction 45144
# Processed transaction 45145
# Processed transaction 45146
# Processed transaction 45147
# Processed transaction 45148
# Processed transaction 45149
# Processed transaction 45150
# Processed transaction 45151
# Processed transaction 45152
# Processed transaction 45153
# Processed transaction 45154
# Processed transaction 45155
# Processed transaction 45156
# Processed transaction 45157
# Processed transaction 45158
# Processed transaction 45159
# Processed transaction 45160
# Processed transaction 45161
# Processed transaction 45162
# Processed transaction 45163
# Processed transaction 45164
# Processed transaction 45165
# Processed transaction 45166
# Processed transaction 45167
# Processed transaction 45168
# Processed transaction 45169
# Processed transaction 45170
# Processed transaction 45171
# Processed transaction 45172
# Processed transaction 45173
# Processed transaction 45174
# Processed transaction 45175
# Processed transaction 45176
# Processed transaction 45177
# Processed transaction 45178
# Processed transaction 45179
# Processed transaction 45180
# Processed transaction 45181
# Processed transaction 45182
# Processed transaction 45183
# Processed transaction 45184
# Processed transaction 45185
# Processed transaction 45186
# Processed transaction 45187
# Processed transaction 45188
# Processed transaction 45189
# Processed transaction 45190
# Processed transaction 45191
# Processed transaction 45192
# Processed transaction 45193
# Processed transaction 45194
# Processed transaction 45195
# Processed transaction 45196
# Processed transaction 45197
# Processed transaction 45198
# Processed transaction 45199
# Processed transaction 45200
# Processed transaction 45201
# Processed transaction 45202
# Processed transaction 45203
# Processed transaction 45204
# Processed transaction 45205
# Processed transaction 45206
# Processed transaction 45207
# Processed transaction 45208
# Processed transaction 45209
# Processed transaction 45210
# Processed transaction 45211
# Processed transaction 45212
# Processed transaction 45213
# Processed transaction 45214
# Processed transaction 45215
# Processed transaction 45216
# Processed transaction 45217
# Processed transaction 45218
# Processed transaction 45219
# Processed transaction 45220
# Processed transaction 45221
# Processed transaction 45222
# Processed transaction 45223
# Processed transaction 45224
# Processed transaction 45225
# Processed transaction 45226
# Processed transaction 45227
# Processed transaction 45228
# Processed transaction 45229
# Processed transaction 45230
# Processed transaction 45231
# Processed transaction 45232
# Processed transaction 45233
# Processed transaction 45234
# Processed transaction 45235
# Processed transaction 45236
# Processed transaction 45237
# Processed transaction 45238
# Processed transaction 45239
# Processed transaction 45240
# Processed transaction 45241
# Processed transaction 45242
# Processed transaction 45243
# Processed transaction 45244
# Processed transaction 45245
# Processed transaction 45246
# Processed transaction 45247
# Processed transaction 45248
# Processed transaction 45249
# Processed transaction 45250
# Processed transaction 45251
# Processed transaction 45252
# Processed transaction 45253
# Processed transaction 45254
# Processed transaction 45255
# Processed transaction 45256
# Processed transaction 45257
# Processed transaction 45258
# Processed transaction 45259
# Processed transaction 45260
# Processed transaction 45261
# Processed transaction 45262
# Processed transaction 45263
# Processed transaction 45264
# Processed transaction 45265
# Processed transaction 45266
# Processed transaction 45267
# Processed transaction 45268
# Processed transaction 45269
# Processed transaction 45270
# Processed transaction 45271
# Processed transaction 45272
# Processed transaction 45273
# Processed transaction 45274
# Processed transaction 45275
# Processed transaction 45276
# Processed transaction 45277
# Processed transaction 45278
# Processed transaction 45279
# Processed transaction 45280
# Processed transaction 45281
# Processed transaction 45282
# Processed transaction 45283
# Processed transaction 45284
# Processed transaction 45285
# Processed transaction 45286
# Processed transaction 45287
# Processed transaction 45288
# Processed transaction 45289
# Processed transaction 45290
# Processed transaction 45291
# Processed transaction 45292
# Processed transaction 45293
# Processed transaction 45294
# Processed transaction 45295
# Processed transaction 45296
# Processed transaction 45297
# Processed transaction 45298
# Processed transaction 45299
# Processed transaction 45300
# Processed transaction 45301
# Processed transaction 45302
# Processed transaction 45303
# Processed transaction 45304
# Processed transaction 45305
# Processed transaction 45306
# Processed transaction 45307
# Processed transaction 45308
# Processed transaction 45309
# Processed transaction 45310
# Processed transaction 45311
# Processed transaction 45312
# Processed transaction 45313
# Processed transaction 45314
# Processed transaction 45315
# Processed transaction 45316
# Processed transaction 45317
# Processed transaction 45318
# Processed transaction 45319
# Processed transaction 45320
# Processed transaction 45321
# Processed transaction 45322
# Processed transaction 45323
# Processed transaction 45324
# Processed transaction 45325
# Processed transaction 45326
# Processed transaction 45327
# Processed transaction 45328
# Processed transaction 45329
# Processed transaction 45330
# Processed transaction 45331
# Processed transaction 45332
# Processed transaction 45333
# Processed transaction 45334
# Processed transaction 45335
# Processed transaction 45336
# Processed transaction 45337
# Processed transaction 45338
# Processed transaction 45339
# Processed transaction 45340
# Processed transaction 45341
# Processed transaction 45342
# Processed transaction 45343
# Processed transaction 45344
# Processed transaction 45345
# Processed transaction 45346
# Processed transaction 45347
# Processed transaction 45348
# Processed transaction 45349
# Processed transaction 45350
# Processed transaction 45351
# Processed transaction 45352
# Processed transaction 45353
# Processed transaction 45354
# Processed transaction 45355
# Processed transaction 45356
# Processed transaction 45357
# Processed transaction 45358
# Processed transaction 45359
# Processed transaction 45360
# Processed transaction 45361
# Processed transaction 45362
# Processed transaction 45363
# Processed transaction 45364
# Processed transaction 45365
# Processed transaction 45366
# Processed transaction 45367
# Processed transaction 45368
# Processed transaction 45369
# Processed transaction 45370
# Processed transaction 45371
# Processed transaction 45372
# Processed transaction 45373
# Processed transaction 45374
# Processed transaction 45375
# Processed transaction 45376
# Processed transaction 45377
# Processed transaction 45378
# Processed transaction 45379
# Processed transaction 45380
# Processed transaction 45381
# Processed transaction 45382
# Processed transaction 45383
# Processed transaction 45384
# Processed transaction 45385
# Processed transaction 45386
# Processed transaction 45387
# Processed transaction 45388
# Processed transaction 45389
# Processed transaction 45390
# Processed transaction 45391
# Processed transaction 45392
# Processed transaction 45393
# Processed transaction 45394
# Processed transaction 45395
# Processed transaction 45396
# Processed transaction 45397
# Processed transaction 45398
# Processed transaction 45399
# Processed transaction 45400
# Processed transaction 45401
# Processed transaction 45402
# Processed transaction 45403
# Processed transaction 45404
# Processed transaction 45405
# Processed transaction 45406
# Processed transaction 45407
# Processed transaction 45408
# Processed transaction 45409
# Processed transaction 45410
# Processed transaction 45411
# Processed transaction 45412
# Processed transaction 45413
# Processed transaction 45414
# Processed transaction 45415
# Processed transaction 45416
# Processed transaction 45417
# Processed transaction 45418
# Processed transaction 45419
# Processed transaction 45420
# Processed transaction 45421
# Processed transaction 45422
# Processed transaction 45423
# Processed transaction 45424
# Processed transaction 45425
# Processed transaction 45426
# Processed transaction 45427
# Processed transaction 45428
# Processed transaction 45429
# Processed transaction 45430
# Processed transaction 45431
# Processed transaction 45432
# Processed transaction 45433
# Processed transaction 45434
# Processed transaction 45435
# Processed transaction 45436
# Processed transaction 45437
# Processed transaction 45438
# Processed transaction 45439
# Processed transaction 45440
# Processed transaction 45441
# Processed transaction 45442
# Processed transaction 45443
# Processed transaction 45444
# Processed transaction 45445
# Processed transaction 45446
# Processed transaction 45447
# Processed transaction 45448
# Processed transaction 45449
# Processed transaction 45450
# Processed transaction 45451
# Processed transaction 45452
# Processed transaction 45453
# Processed transaction 45454
# Processed transaction 45455
# Processed transaction 45456
# Processed transaction 45457
# Processed transaction 45458
# Processed transaction 45459
# Processed transaction 45460
# Processed transaction 45461
# Processed transaction 45462
# Processed transaction 45463
# Processed transaction 45464
# Processed transaction 45465
# Processed transaction 45466
# Processed transaction 45467
# Processed transaction 45468
# Processed transaction 45469
# Processed transaction 45470
# Processed transaction 45471
# Processed transaction 45472
# Processed transaction 45473
# Processed transaction 45474
# Processed transaction 45475
# Processed transaction 45476
# Processed transaction 45477
# Processed transaction 45478
# Processed transaction 45479
# Processed transaction 45480
# Processed transaction 45481
# Processed transaction 45482
# Processed transaction 45483
# Processed transaction 45484
# Processed transaction 45485
# Processed transaction 45486
# Processed transaction 45487
# Processed transaction 45488
# Processed transaction 45489
# Processed transaction 45490
# Processed transaction 45491
# Processed transaction 45492
# Processed transaction 45493
# Processed transaction 45494
# Processed transaction 45495
# Processed transaction 45496
# Processed transaction 45497
# Processed transaction 45498
# Processed transaction 45499
# Processed transaction 45500
# Processed transaction 45501
# Processed transaction 45502
# Processed transaction 45503
# Processed transaction 45504
# Processed transaction 45505
# Processed transaction 45506
# Processed transaction 45507
# Processed transaction 45508
# Processed transaction 45509
# Processed transaction 45510
# Processed transaction 45511
# Processed transaction 45512
# Processed transaction 45513
# Processed transaction 45514
# Processed transaction 45515
# Processed transaction 45516
# Processed transaction 45517
# Processed transaction 45518
# Processed transaction 45519
# Processed transaction 45520
# Processed transaction 45521
# Processed transaction 45522
# Processed transaction 45523
# Processed transaction 45524
# Processed transaction 45525
# Processed transaction 45526
# Processed transaction 45527
# Processed transaction 45528
# Processed transaction 45529
# Processed transaction 45530
# Processed transaction 45531
# Processed transaction 45532
# Processed transaction 45533
# Processed transaction 45534
# Processed transaction 45535
# Processed transaction 45536
# Processed transaction 45537
# Processed transaction 45538
# Processed transaction 45539
# Processed transaction 45540
# Processed transaction 45541
# Processed transaction 45542
# Processed transaction 45543
# Processed transaction 45544
# Processed transaction 45545
# Processed transaction 45546
# Processed transaction 45547
# Processed transaction 45548
# Processed transaction 45549
# Processed transaction 45550
# Processed transaction 45551
# Processed transaction 45552
# Processed transaction 45553
# Processed transaction 45554
# Processed transaction 45555
# Processed transaction 45556
# Processed transaction 45557
# Processed transaction 45558
# Processed transaction 45559
# Processed transaction 45560
# Processed transaction 45561
# Processed transaction 45562
# Processed transaction 45563
# Processed transaction 45564
# Processed transaction 45565
# Processed transaction 45566
# Processed transaction 45567
# Processed transaction 45568
# Processed transaction 45569
# Processed transaction 45570
# Processed transaction 45571
# Processed transaction 45572
# Processed transaction 45573
# Processed transaction 45574
# Processed transaction 45575
# Processed transaction 45576
# Processed transaction 45577
# Processed transaction 45578
# Processed transaction 45579
# Processed transaction 45580
# Processed transaction 45581
# Processed transaction 45582
# Processed transaction 45583
# Processed transaction 45584
# Processed transaction 45585
# Processed transaction 45586
# Processed transaction 45587
# Processed transaction 45588
# Processed transaction 45589
# Processed transaction 45590
# Processed transaction 45591
# Processed transaction 45592
# Processed transaction 45593
# Processed transaction 45594
# Processed transaction 45595
# Processed transaction 45596
# Processed transaction 45597
# Processed transaction 45598
# Processed transaction 45599
# Processed transaction 45600
# Processed transaction 45601
# Processed transaction 45602
# Processed transaction 45603
# Processed transaction 45604
# Processed transaction 45605
# Processed transaction 45606
# Processed transaction 45607
# Processed transaction 45608
# Processed transaction 45609
# Processed transaction 45610
# Processed transaction 45611
# Processed transaction 45612
# Processed transaction 45613
# Processed transaction 45614
# Processed transaction 45615
# Processed transaction 45616
# Processed transaction 45617
# Processed transaction 45618
# Processed transaction 45619
# Processed transaction 45620
# Processed transaction 45621
# Processed transaction 45622
# Processed transaction 45623
# Processed transaction 45624
# Processed transaction 45625
# Processed transaction 45626
# Processed transaction 45627
# Processed transaction 45628
# Processed transaction 45629
# Processed transaction 45630
# Processed transaction 45631
# Processed transaction 45632
# Processed transaction 45633
# Processed transaction 45634
# Processed transaction 45635
# Processed transaction 45636
# Processed transaction 45637
# Processed transaction 45638
# Processed transaction 45639
# Processed transaction 45640
# Processed transaction 45641
# Processed transaction 45642
# Processed transaction 45643
# Processed transaction 45644
# Processed transaction 45645
# Processed transaction 45646
# Processed transaction 45647
# Processed transaction 45648
# Processed transaction 45649
# Processed transaction 45650
# Processed transaction 45651
# Processed transaction 45652
# Processed transaction 45653
# Processed transaction 45654
# Processed transaction 45655
# Processed transaction 45656
# Processed transaction 45657
# Processed transaction 45658
# Processed transaction 45659
# Processed transaction 45660
# Processed transaction 45661
# Processed transaction 45662
# Processed transaction 45663
# Processed transaction 45664
# Processed transaction 45665
# Processed transaction 45666
# Processed transaction 45667
# Processed transaction 45668
# Processed transaction 45669
# Processed transaction 45670
# Processed transaction 45671
# Processed transaction 45672
# Processed transaction 45673
# Processed transaction 45674
# Processed transaction 45675
# Processed transaction 45676
# Processed transaction 45677
# Processed transaction 45678
# Processed transaction 45679
# Processed transaction 45680
# Processed transaction 45681
# Processed transaction 45682
# Processed transaction 45683
# Processed transaction 45684
# Processed transaction 45685
# Processed transaction 45686
# Processed transaction 45687
# Processed transaction 45688
# Processed transaction 45689
# Processed transaction 45690
# Processed transaction 45691
# Processed transaction 45692
# Processed transaction 45693
# Processed transaction 45694
# Processed transaction 45695
# Processed transaction 45696
# Processed transaction 45697
# Processed transaction 45698
# Processed transaction 45699
# Processed transaction 45700
# Processed transaction 45701
# Processed transaction 45702
# Processed transaction 45703
# Processed transaction 45704
# Processed transaction 45705
# Processed transaction 45706
# Processed transaction 45707
# Processed transaction 45708
# Processed transaction 45709
# Processed transaction 45710
# Processed transaction 45711
# Processed transaction 45712
# Processed transaction 45713
# Processed transaction 45714
# Processed transaction 45715
# Processed transaction 45716
# Processed transaction 45717
# Processed transaction 45718
# Processed transaction 45719
# Processed transaction 45720
# Processed transaction 45721
# Processed transaction 45722
# Processed transaction 45723
# Processed transaction 45724
# Processed transaction 45725
# Processed transaction 45726
# Processed transaction 45727
# Processed transaction 45728
# Processed transaction 45729
# Processed transaction 45730
# Processed transaction 45731
# Processed transaction 45732
# Processed transaction 45733
# Processed transaction 45734
# Processed transaction 45735
# Processed transaction 45736
# Processed transaction 45737
# Processed transaction 45738
# Processed transaction 45739
# Processed transaction 45740
# Processed transaction 45741
# Processed transaction 45742
# Processed transaction 45743
# Processed transaction 45744
# Processed transaction 45745
# Processed transaction 45746
# Processed transaction 45747
# Processed transaction 45748
# Processed transaction 45749
# Processed transaction 45750
# Processed transaction 45751
# Processed transaction 45752
# Processed transaction 45753
# Processed transaction 45754
# Processed transaction 45755
# Processed transaction 45756
# Processed transaction 45757
# Processed transaction 45758
# Processed transaction 45759
# Processed transaction 45760
# Processed transaction 45761
# Processed transaction 45762
# Processed transaction 45763
# Processed transaction 45764
# Processed transaction 45765
# Processed transaction 45766
# Processed transaction 45767
# Processed transaction 45768
# Processed transaction 45769
# Processed transaction 45770
# Processed transaction 45771
# Processed transaction 45772
# Processed transaction 45773
# Processed transaction 45774
# Processed transaction 45775
# Processed transaction 45776
# Processed transaction 45777
# Processed transaction 45778
# Processed transaction 45779
# Processed transaction 45780
# Processed transaction 45781
# Processed transaction 45782
# Processed transaction 45783
# Processed transaction 45784
# Processed transaction 45785
# Processed transaction 45786
# Processed transaction 45787
# Processed transaction 45788
# Processed transaction 45789
# Processed transaction 45790
# Processed transaction 45791
# Processed transaction 45792
# Processed transaction 45793
# Processed transaction 45794
# Processed transaction 45795
# Processed transaction 45796
# Processed transaction 45797
# Processed transaction 45798
# Processed transaction 45799
# Processed transaction 45800
# Processed transaction 45801
# Processed transaction 45802
# Processed transaction 45803
# Processed transaction 45804
# Processed transaction 45805
# Processed transaction 45806
# Processed transaction 45807
# Processed transaction 45808
# Processed transaction 45809
# Processed transaction 45810
# Processed transaction 45811
# Processed transaction 45812
# Processed transaction 45813
# Processed transaction 45814
# Processed transaction 45815
# Processed transaction 45816
# Processed transaction 45817
# Processed transaction 45818
# Processed transaction 45819
# Processed transaction 45820
# Processed transaction 45821
# Processed transaction 45822
# Processed transaction 45823
# Processed transaction 45824
# Processed transaction 45825
# Processed transaction 45826
# Processed transaction 45827
# Processed transaction 45828
# Processed transaction 45829
# Processed transaction 45830
# Processed transaction 45831
# Processed transaction 45832
# Processed transaction 45833
# Processed transaction 45834
# Processed transaction 45835
# Processed transaction 45836
# Processed transaction 45837
# Processed transaction 45838
# Processed transaction 45839
# Processed transaction 45840
# Processed transaction 45841
# Processed transaction 45842
# Processed transaction 45843
# Processed transaction 45844
# Processed transaction 45845
# Processed transaction 45846
# Processed transaction 45847
# Processed transaction 45848
# Processed transaction 45849
# Processed transaction 45850
# Processed transaction 45851
# Processed transaction 45852
# Processed transaction 45853
# Processed transaction 45854
# Processed transaction 45855
# Processed transaction 45856
# Processed transaction 45857
# Processed transaction 45858
# Processed transaction 45859
# Processed transaction 45860
# Processed transaction 45861
# Processed transaction 45862
# Processed transaction 45863
# Processed transaction 45864
# Processed transaction 45865
# Processed transaction 45866
# Processed transaction 45867
# Processed transaction 45868
# Processed transaction 45869
# Processed transaction 45870
# Processed transaction 45871
# Processed transaction 45872
# Processed transaction 45873
# Processed transaction 45874
# Processed transaction 45875
# Processed transaction 45876
# Processed transaction 45877
# Processed transaction 45878
# Processed transaction 45879
# Processed transaction 45880
# Processed transaction 45881
# Processed transaction 45882
# Processed transaction 45883
# Processed transaction 45884
# Processed transaction 45885
# Processed transaction 45886
# Processed transaction 45887
# Processed transaction 45888
# Processed transaction 45889
# Processed transaction 45890
# Processed transaction 45891
# Processed transaction 45892
# Processed transaction 45893
# Processed transaction 45894
# Processed transaction 45895
# Processed transaction 45896
# Processed transaction 45897
# Processed transaction 45898
# Processed transaction 45899
# Processed transaction 45900
# Processed transaction 45901
# Processed transaction 45902
# Processed transaction 45903
# Processed transaction 45904
# Processed transaction 45905
# Processed transaction 45906
# Processed transaction 45907
# Processed transaction 45908
# Processed transaction 45909
# Processed transaction 45910
# Processed transaction 45911
# Processed transaction 45912
# Processed transaction 45913
# Processed transaction 45914
# Processed transaction 45915
# Processed transaction 45916
# Processed transaction 45917
# Processed transaction 45918
# Processed transaction 45919
# Processed transaction 45920
# Processed transaction 45921
# Processed transaction 45922
# Processed transaction 45923
# Processed transaction 45924
# Processed transaction 45925
# Processed transaction 45926
# Processed transaction 45927
# Processed transaction 45928
# Processed transaction 45929
# Processed transaction 45930
# Processed transaction 45931
# Processed transaction 45932
# Processed transaction 45933
# Processed transaction 45934
# Processed transaction 45935
# Processed transaction 45936
# Processed transaction 45937
# Processed transaction 45938
# Processed transaction 45939
# Processed transaction 45940
# Processed transaction 45941
# Processed transaction 45942
# Processed transaction 45943
# Processed transaction 45944
# Processed transaction 45945
# Processed transaction 45946
# Processed transaction 45947
# Processed transaction 45948
# Processed transaction 45949
# Processed transaction 45950
# Processed transaction 45951
# Processed transaction 45952
# Processed transaction 45953
# Processed transaction 45954
# Processed transaction 45955
# Processed transaction 45956
# Processed transaction 45957
# Processed transaction 45958
# Processed transaction 45959
# Processed transaction 45960
# Processed transaction 45961
# Processed transaction 45962
# Processed transaction 45963
# Processed transaction 45964
# Processed transaction 45965
# Processed transaction 45966
# Processed transaction 45967
# Processed transaction 45968
# Processed transaction 45969
# Processed transaction 45970
# Processed transaction 45971
# Processed transaction 45972
# Processed transaction 45973
# Processed transaction 45974
# Processed transaction 45975
# Processed transaction 45976
# Processed transaction 45977
# Processed transaction 45978
# Processed transaction 45979
# Processed transaction 45980
# Processed transaction 45981
# Processed transaction 45982
# Processed transaction 45983
# Processed transaction 45984
# Processed transaction 45985
# Processed transaction 45986
# Processed transaction 45987
# Processed transaction 45988
# Processed transaction 45989
# Processed transaction 45990
# Processed transaction 45991
# Processed transaction 45992
# Processed transaction 45993
# Processed transaction 45994
# Processed transaction 45995
# Processed transaction 45996
# Processed transaction 45997
# Processed transaction 45998
# Processed transaction 45999
# Processed transaction 46000
# Processed transaction 46001
# Processed transaction 46002
# Processed transaction 46003
# Processed transaction 46004
# Processed transaction 46005
# Processed transaction 46006
# Processed transaction 46007
# Processed transaction 46008
# Processed transaction 46009
# Processed transaction 46010
# Processed transaction 46011
# Processed transaction 46012
# Processed transaction 46013
# Processed transaction 46014
# Processed transaction 46015
# Processed transaction 46016
# Processed transaction 46017
# Processed transaction 46018
# Processed transaction 46019
# Processed transaction 46020
# Processed transaction 46021
# Processed transaction 46022
# Processed transaction 46023
# Processed transaction 46024
# Processed transaction 46025
# Processed transaction 46026
# Processed transaction 46027
# Processed transaction 46028
# Processed transaction 46029
# Processed transaction 46030
# Processed transaction 46031
# Processed transaction 46032
# Processed transaction 46033
# Processed transaction 46034
# Processed transaction 46035
# Processed transaction 46036
# Processed transaction 46037
# Processed transaction 46038
# Processed transaction 46039
# Processed transaction 46040
# Processed transaction 46041
# Processed transaction 46042
# Processed transaction 46043
# Processed transaction 46044
# Processed transaction 46045
# Processed transaction 46046
# Processed transaction 46047
# Processed transaction 46048
# Processed transaction 46049
# Processed transaction 46050
# Processed transaction 46051
# Processed transaction 46052
# Processed transaction 46053
# Processed transaction 46054
# Processed transaction 46055
# Processed transaction 46056
# Processed transaction 46057
# Processed transaction 46058
# Processed transaction 46059
# Processed transaction 46060
# Processed transaction 46061
# Processed transaction 46062
# Processed transaction 46063
# Processed transaction 46064
# Processed transaction 46065
# Processed transaction 46066
# Processed transaction 46067
# Processed transaction 46068
# Processed transaction 46069
# Processed transaction 46070
# Processed transaction 46071
# Processed transaction 46072
# Processed transaction 46073
# Processed transaction 46074
# Processed transaction 46075
# Processed transaction 46076
# Processed transaction 46077
# Processed transaction 46078
# Processed transaction 46079
# Processed transaction 46080
# Processed transaction 46081
# Processed transaction 46082
# Processed transaction 46083
# Processed transaction 46084
# Processed transaction 46085
# Processed transaction 46086
# Processed transaction 46087
# Processed transaction 46088
# Processed transaction 46089
# Processed transaction 46090
# Processed transaction 46091
# Processed transaction 46092
# Processed transaction 46093
# Processed transaction 46094
# Processed transaction 46095
# Processed transaction 46096
# Processed transaction 46097
# Processed transaction 46098
# Processed transaction 46099
# Processed transaction 46100
# Processed transaction 46101
# Processed transaction 46102
# Processed transaction 46103
# Processed transaction 46104
# Processed transaction 46105
# Processed transaction 46106
# Processed transaction 46107
# Processed transaction 46108
# Processed transaction 46109
# Processed transaction 46110
# Processed transaction 46111
# Processed transaction 46112
# Processed transaction 46113
# Processed transaction 46114
# Processed transaction 46115
# Processed transaction 46116
# Processed transaction 46117
# Processed transaction 46118
# Processed transaction 46119
# Processed transaction 46120
# Processed transaction 46121
# Processed transaction 46122
# Processed transaction 46123
# Processed transaction 46124
# Processed transaction 46125
# Processed transaction 46126
# Processed transaction 46127
# Processed transaction 46128
# Processed transaction 46129
# Processed transaction 46130
# Processed transaction 46131
# Processed transaction 46132
# Processed transaction 46133
# Processed transaction 46134
# Processed transaction 46135
# Processed transaction 46136
# Processed transaction 46137
# Processed transaction 46138
# Processed transaction 46139
# Processed transaction 46140
# Processed transaction 46141
# Processed transaction 46142
# Processed transaction 46143
# Processed transaction 46144
# Processed transaction 46145
# Processed transaction 46146
# Processed transaction 46147
# Processed transaction 46148
# Processed transaction 46149
# Processed transaction 46150
# Processed transaction 46151
# Processed transaction 46152
# Processed transaction 46153
# Processed transaction 46154
# Processed transaction 46155
# Processed transaction 46156
# Processed transaction 46157
# Processed transaction 46158
# Processed transaction 46159
# Processed transaction 46160
# Processed transaction 46161
# Processed transaction 46162
# Processed transaction 46163
# Processed transaction 46164
# Processed transaction 46165
# Processed transaction 46166
# Processed transaction 46167
# Processed transaction 46168
# Processed transaction 46169
# Processed transaction 46170
# Processed transaction 46171
# Processed transaction 46172
# Processed transaction 46173
# Processed transaction 46174
# Processed transaction 46175
# Processed transaction 46176
# Processed transaction 46177
# Processed transaction 46178
# Processed transaction 46179
# Processed transaction 46180
# Processed transaction 46181
# Processed transaction 46182
# Processed transaction 46183
# Processed transaction 46184
# Processed transaction 46185
# Processed transaction 46186
# Processed transaction 46187
# Processed transaction 46188
# Processed transaction 46189
# Processed transaction 46190
# Processed transaction 46191
# Processed transaction 46192
# Processed transaction 46193
# Processed transaction 46194
# Processed transaction 46195
# Processed transaction 46196
# Processed transaction 46197
# Processed transaction 46198
# Processed transaction 46199
# Processed transaction 46200
# Processed transaction 46201
# Processed transaction 46202
# Processed transaction 46203
# Processed transaction 46204
# Processed transaction 46205
# Processed transaction 46206
# Processed transaction 46207
# Processed transaction 46208
# Processed transaction 46209
# Processed transaction 46210
# Processed transaction 46211
# Processed transaction 46212
# Processed transaction 46213
# Processed transaction 46214
# Processed transaction 46215
# Processed transaction 46216
# Processed transaction 46217
# Processed transaction 46218
# Processed transaction 46219
# Processed transaction 46220
# Processed transaction 46221
# Processed transaction 46222
# Processed transaction 46223
# Processed transaction 46224
# Processed transaction 46225
# Processed transaction 46226
# Processed transaction 46227
# Processed transaction 46228
# Processed transaction 46229
# Processed transaction 46230
# Processed transaction 46231
# Processed transaction 46232
# Processed transaction 46233
# Processed transaction 46234
# Processed transaction 46235
# Processed transaction 46236
# Processed transaction 46237
# Processed transaction 46238
# Processed transaction 46239
# Processed transaction 46240
# Processed transaction 46241
# Processed transaction 46242
# Processed transaction 46243
# Processed transaction 46244
# Processed transaction 46245
# Processed transaction 46246
# Processed transaction 46247
# Processed transaction 46248
# Processed transaction 46249
# Processed transaction 46250
# Processed transaction 46251
# Processed transaction 46252
# Processed transaction 46253
# Processed transaction 46254
# Processed transaction 46255
# Processed transaction 46256
# Processed transaction 46257
# Processed transaction 46258
# Processed transaction 46259
# Processed transaction 46260
# Processed transaction 46261
# Processed transaction 46262
# Processed transaction 46263
# Processed transaction 46264
# Processed transaction 46265
# Processed transaction 46266
# Processed transaction 46267
# Processed transaction 46268
# Processed transaction 46269
# Processed transaction 46270
# Processed transaction 46271
# Processed transaction 46272
# Processed transaction 46273
# Processed transaction 46274
# Processed transaction 46275
# Processed transaction 46276
# Processed transaction 46277
# Processed transaction 46278
# Processed transaction 46279
# Processed transaction 46280
# Processed transaction 46281
# Processed transaction 46282
# Processed transaction 46283
# Processed transaction 46284
# Processed transaction 46285
# Processed transaction 46286
# Processed transaction 46287
# Processed transaction 46288
# Processed transaction 46289
# Processed transaction 46290
# Processed transaction 46291
# Processed transaction 46292
# Processed transaction 46293
# Processed transaction 46294
# Processed transaction 46295
# Processed transaction 46296
# Processed transaction 46297
# Processed transaction 46298
# Processed transaction 46299
# Processed transaction 46300
# Processed transaction 46301
# Processed transaction 46302
# Processed transaction 46303
# Processed transaction 46304
# Processed transaction 46305
# Processed transaction 46306
# Processed transaction 46307
# Processed transaction 46308
# Processed transaction 46309
# Processed transaction 46310
# Processed transaction 46311
# Processed transaction 46312
# Processed transaction 46313
# Processed transaction 46314
# Processed transaction 46315
# Processed transaction 46316
# Processed transaction 46317
# Processed transaction 46318
# Processed transaction 46319
# Processed transaction 46320
# Processed transaction 46321
# Processed transaction 46322
# Processed transaction 46323
# Processed transaction 46324
# Processed transaction 46325
# Processed transaction 46326
# Processed transaction 46327
# Processed transaction 46328
# Processed transaction 46329
# Processed transaction 46330
# Processed transaction 46331
# Processed transaction 46332
# Processed transaction 46333
# Processed transaction 46334
# Processed transaction 46335
# Processed transaction 46336
# Processed transaction 46337
# Processed transaction 46338
# Processed transaction 46339
# Processed transaction 46340
# Processed transaction 46341
# Processed transaction 46342
# Processed transaction 46343
# Processed transaction 46344
# Processed transaction 46345
# Processed transaction 46346
# Processed transaction 46347
# Processed transaction 46348
# Processed transaction 46349
# Processed transaction 46350
# Processed transaction 46351
# Processed transaction 46352
# Processed transaction 46353
# Processed transaction 46354
# Processed transaction 46355
# Processed transaction 46356
# Processed transaction 46357
# Processed transaction 46358
# Processed transaction 46359
# Processed transaction 46360
# Processed transaction 46361
# Processed transaction 46362
# Processed transaction 46363
# Processed transaction 46364
# Processed transaction 46365
# Processed transaction 46366
# Processed transaction 46367
# Processed transaction 46368
# Processed transaction 46369
# Processed transaction 46370
# Processed transaction 46371
# Processed transaction 46372
# Processed transaction 46373
# Processed transaction 46374
# Processed transaction 46375
# Processed transaction 46376
# Processed transaction 46377
# Processed transaction 46378
# Processed transaction 46379
# Processed transaction 46380
# Processed transaction 46381
# Processed transaction 46382
# Processed transaction 46383
# Processed transaction 46384
# Processed transaction 46385
# Processed transaction 46386
# Processed transaction 46387
# Processed transaction 46388
# Processed transaction 46389
# Processed transaction 46390
# Processed transaction 46391
# Processed transaction 46392
# Processed transaction 46393
# Processed transaction 46394
# Processed transaction 46395
# Processed transaction 46396
# Processed transaction 46397
# Processed transaction 46398
# Processed transaction 46399
# Processed transaction 46400
# Processed transaction 46401
# Processed transaction 46402
# Processed transaction 46403
# Processed transaction 46404
# Processed transaction 46405
# Processed transaction 46406
# Processed transaction 46407
# Processed transaction 46408
# Processed transaction 46409
# Processed transaction 46410
# Processed transaction 46411
# Processed transaction 46412
# Processed transaction 46413
# Processed transaction 46414
# Processed transaction 46415
# Processed transaction 46416
# Processed transaction 46417
# Processed transaction 46418
# Processed transaction 46419
# Processed transaction 46420
# Processed transaction 46421
# Processed transaction 46422
# Processed transaction 46423
# Processed transaction 46424
# Processed transaction 46425
# Processed transaction 46426
# Processed transaction 46427
# Processed transaction 46428
# Processed transaction 46429
# Processed transaction 46430
# Processed transaction 46431
# Processed transaction 46432
# Processed transaction 46433
# Processed transaction 46434
# Processed transaction 46435
# Processed transaction 46436
# Processed transaction 46437
# Processed transaction 46438
# Processed transaction 46439
# Processed transaction 46440
# Processed transaction 46441
# Processed transaction 46442
# Processed transaction 46443
# Processed transaction 46444
# Processed transaction 46445
# Processed transaction 46446
# Processed transaction 46447
# Processed transaction 46448
# Processed transaction 46449
# Processed transaction 46450
# Processed transaction 46451
# Processed transaction 46452
# Processed transaction 46453
# Processed transaction 46454
# Processed transaction 46455
# Processed transaction 46456
# Processed transaction 46457
# Processed transaction 46458
# Processed transaction 46459
# Processed transaction 46460
# Processed transaction 46461
# Processed transaction 46462
# Processed transaction 46463
# Processed transaction 46464
# Processed transaction 46465
# Processed transaction 46466
# Processed transaction 46467
# Processed transaction 46468
# Processed transaction 46469
# Processed transaction 46470
# Processed transaction 46471
# Processed transaction 46472
# Processed transaction 46473
# Processed transaction 46474
# Processed transaction 46475
# Processed transaction 46476
# Processed transaction 46477
# Processed transaction 46478
# Processed transaction 46479
# Processed transaction 46480
# Processed transaction 46481
# Processed transaction 46482
# Processed transaction 46483
# Processed transaction 46484
# Processed transaction 46485
# Processed transaction 46486
# Processed transaction 46487
# Processed transaction 46488
# Processed transaction 46489
# Processed transaction 46490
# Processed transaction 46491
# Processed transaction 46492
# Processed transaction 46493
# Processed transaction 46494
# Processed transaction 46495
# Processed transaction 46496
# Processed transaction 46497
# Processed transaction 46498
# Processed transaction 46499
# Processed transaction 46500
# Processed transaction 46501
# Processed transaction 46502
# Processed transaction 46503
# Processed transaction 46504
# Processed transaction 46505
# Processed transaction 46506
# Processed transaction 46507
# Processed transaction 46508
# Processed transaction 46509
# Processed transaction 46510
# Processed transaction 46511
# Processed transaction 46512
# Processed transaction 46513
# Processed transaction 46514
# Processed transaction 46515
# Processed transaction 46516
# Processed transaction 46517
# Processed transaction 46518
# Processed transaction 46519
# Processed transaction 46520
# Processed transaction 46521
# Processed transaction 46522
# Processed transaction 46523
# Processed transaction 46524
# Processed transaction 46525
# Processed transaction 46526
# Processed transaction 46527
# Processed transaction 46528
# Processed transaction 46529
# Processed transaction 46530
# Processed transaction 46531
# Processed transaction 46532
# Processed transaction 46533
# Processed transaction 46534
# Processed transaction 46535
# Processed transaction 46536
# Processed transaction 46537
# Processed transaction 46538
# Processed transaction 46539
# Processed transaction 46540
# Processed transaction 46541
# Processed transaction 46542
# Processed transaction 46543
# Processed transaction 46544
# Processed transaction 46545
# Processed transaction 46546
# Processed transaction 46547
# Processed transaction 46548
# Processed transaction 46549
# Processed transaction 46550
# Processed transaction 46551
# Processed transaction 46552
# Processed transaction 46553
# Processed transaction 46554
# Processed transaction 46555
# Processed transaction 46556
# Processed transaction 46557
# Processed transaction 46558
# Processed transaction 46559
# Processed transaction 46560
# Processed transaction 46561
# Processed transaction 46562
# Processed transaction 46563
# Processed transaction 46564
# Processed transaction 46565
# Processed transaction 46566
# Processed transaction 46567
# Processed transaction 46568
# Processed transaction 46569
# Processed transaction 46570
# Processed transaction 46571
# Processed transaction 46572
# Processed transaction 46573
# Processed transaction 46574
# Processed transaction 46575
# Processed transaction 46576
# Processed transaction 46577
# Processed transaction 46578
# Processed transaction 46579
# Processed transaction 46580
# Processed transaction 46581
# Processed transaction 46582
# Processed transaction 46583
# Processed transaction 46584
# Processed transaction 46585
# Processed transaction 46586
# Processed transaction 46587
# Processed transaction 46588
# Processed transaction 46589
# Processed transaction 46590
# Processed transaction 46591
# Processed transaction 46592
# Processed transaction 46593
# Processed transaction 46594
# Processed transaction 46595
# Processed transaction 46596
# Processed transaction 46597
# Processed transaction 46598
# Processed transaction 46599
# Processed transaction 46600
# Processed transaction 46601
# Processed transaction 46602
# Processed transaction 46603
# Processed transaction 46604
# Processed transaction 46605
# Processed transaction 46606
# Processed transaction 46607
# Processed transaction 46608
# Processed transaction 46609
# Processed transaction 46610
# Processed transaction 46611
# Processed transaction 46612
# Processed transaction 46613
# Processed transaction 46614
# Processed transaction 46615
# Processed transaction 46616
# Processed transaction 46617
# Processed transaction 46618
# Processed transaction 46619
# Processed transaction 46620
# Processed transaction 46621
# Processed transaction 46622
# Processed transaction 46623
# Processed transaction 46624
# Processed transaction 46625
# Processed transaction 46626
# Processed transaction 46627
# Processed transaction 46628
# Processed transaction 46629
# Processed transaction 46630
# Processed transaction 46631
# Processed transaction 46632
# Processed transaction 46633
# Processed transaction 46634
# Processed transaction 46635
# Processed transaction 46636
# Processed transaction 46637
# Processed transaction 46638
# Processed transaction 46639
# Processed transaction 46640
# Processed transaction 46641
# Processed transaction 46642
# Processed transaction 46643
# Processed transaction 46644
# Processed transaction 46645
# Processed transaction 46646
# Processed transaction 46647
# Processed transaction 46648
# Processed transaction 46649
# Processed transaction 46650
# Processed transaction 46651
# Processed transaction 46652
# Processed transaction 46653
# Processed transaction 46654
# Processed transaction 46655
# Processed transaction 46656
# Processed transaction 46657
# Processed transaction 46658
# Processed transaction 46659
# Processed transaction 46660
# Processed transaction 46661
# Processed transaction 46662
# Processed transaction 46663
# Processed transaction 46664
# Processed transaction 46665
# Processed transaction 46666
# Processed transaction 46667
# Processed transaction 46668
# Processed transaction 46669
# Processed transaction 46670
# Processed transaction 46671
# Processed transaction 46672
# Processed transaction 46673
# Processed transaction 46674
# Processed transaction 46675
# Processed transaction 46676
# Processed transaction 46677
# Processed transaction 46678
# Processed transaction 46679
# Processed transaction 46680
# Processed transaction 46681
# Processed transaction 46682
# Processed transaction 46683
# Processed transaction 46684
# Processed transaction 46685
# Processed transaction 46686
# Processed transaction 46687
# Processed transaction 46688
# Processed transaction 46689
# Processed transaction 46690
# Processed transaction 46691
# Processed transaction 46692
# Processed transaction 46693
# Processed transaction 46694
# Processed transaction 46695
# Processed transaction 46696
# Processed transaction 46697
# Processed transaction 46698
# Processed transaction 46699
# Processed transaction 46700
# Processed transaction 46701
# Processed transaction 46702
# Processed transaction 46703
# Processed transaction 46704
# Processed transaction 46705
# Processed transaction 46706
# Processed transaction 46707
# Processed transaction 46708
# Processed transaction 46709
# Processed transaction 46710
# Processed transaction 46711
# Processed transaction 46712
# Processed transaction 46713
# Processed transaction 46714
# Processed transaction 46715
# Processed transaction 46716
# Processed transaction 46717
# Processed transaction 46718
# Processed transaction 46719
# Processed transaction 46720
# Processed transaction 46721
# Processed transaction 46722
# Processed transaction 46723
# Processed transaction 46724
# Processed transaction 46725
# Processed transaction 46726
# Processed transaction 46727
# Processed transaction 46728
# Processed transaction 46729
# Processed transaction 46730
# Processed transaction 46731
# Processed transaction 46732
# Processed transaction 46733
# Processed transaction 46734
# Processed transaction 46735
# Processed transaction 46736
# Processed transaction 46737
# Processed transaction 46738
# Processed transaction 46739
# Processed transaction 46740
# Processed transaction 46741
# Processed transaction 46742
# Processed transaction 46743
# Processed transaction 46744
# Processed transaction 46745
# Processed transaction 46746
# Processed transaction 46747
# Processed transaction 46748
# Processed transaction 46749
# Processed transaction 46750
# Processed transaction 46751
# Processed transaction 46752
# Processed transaction 46753
# Processed transaction 46754
# Processed transaction 46755
# Processed transaction 46756
# Processed transaction 46757
# Processed transaction 46758
# Processed transaction 46759
# Processed transaction 46760
# Processed transaction 46761
# Processed transaction 46762
# Processed transaction 46763
# Processed transaction 46764
# Processed transaction 46765
# Processed transaction 46766
# Processed transaction 46767
# Processed transaction 46768
# ...
# Processed transaction 49626
# Processed transaction 49627
# Processed transaction 49628
# Processed transaction 49629
# Processed transaction 49630
# Processed transaction 49631
# Processed transaction 49632
# Processed transaction 49633
# Processed transaction 49634
# Processed transaction 49635
# Processed transaction 49636
# Processed transaction 49637
# Processed transaction 49638
# Processed transaction 49639
# Processed transaction 49640
# Processed transaction 49641
# Processed transaction 49642
# Processed transaction 49643
# Processed transaction 49644
# Processed transaction 49645
# Processed transaction 49646
# Processed transaction 49647
# Processed transaction 49648
# Processed transaction 49649
# Processed transaction 49650
# Processed transaction 49651
# Processed transaction 49652
# Processed transaction 49653
# Processed transaction 49654
# Processed transaction 49655
# Processed transaction 49656
# Processed transaction 49657
# Processed transaction 49658
# Processed transaction 49659
# Processed transaction 49660
# Processed transaction 49661
# Processed transaction 49662
# Processed transaction 49663
# Processed transaction 49664
# Processed transaction 49665
# Processed transaction 49666
# Processed transaction 49667
# Processed transaction 49668
# Processed transaction 49669
# Processed transaction 49670
# Processed transaction 49671
# Processed transaction 49672
# Processed transaction 49673
# Processed transaction 49674
# Processed transaction 49675
# Processed transaction 49676
# Processed transaction 49677
# Processed transaction 49678
# Processed transaction 49679
# Processed transaction 49680
# Processed transaction 49681
# Processed transaction 49682
# Processed transaction 49683
# Processed transaction 49684
# Processed transaction 49685
# Processed transaction 49686
# Processed transaction 49687
# Processed transaction 49688
# Processed transaction 49689
# Processed transaction 49690
# Processed transaction 49691
# Processed transaction 49692
# Processed transaction 49693
# Processed transaction 49694
# Processed transaction 49695
# Processed transaction 49696
# Processed transaction 49697
# Processed transaction 49698
# Processed transaction 49699
# Processed transaction 49700
# Processed transaction 49701
# Processed transaction 49702
# Processed transaction 49703
# Processed transaction 49704
# Processed transaction 49705
# Processed transaction 49706
# Processed transaction 49707
# Processed transaction 49708
# Processed transaction 49709
# Processed transaction 49710
# Processed transaction 49711
# Processed transaction 49712
# Processed transaction 49713
# Processed transaction 49714
# Processed transaction 49715
# Processed transaction 49716
# Processed transaction 49717
# Processed transaction 49718
# Processed transaction 49719
# Processed transaction 49720
# Processed transaction 49721
# Processed transaction 49722
# Processed transaction 49723
# Processed transaction 49724
# Processed transaction 49725
# Processed transaction 49726
# Processed transaction 49727
# Processed transaction 49728
# Processed transaction 49729
# Processed transaction 49730
# Processed transaction 49731
# Processed transaction 49732
# Processed transaction 49733
# Processed transaction 49734
# Processed transaction 49735
# Processed transaction 49736
# Processed transaction 49737
# Processed transaction 49738
# Processed transaction 49739
# Processed transaction 49740
# Processed transaction 49741
# Processed transaction 49742
# Processed transaction 49743
# Processed transaction 49744
# Processed transaction 49745
# Processed transaction 49746
# Processed transaction 49747
# Processed transaction 49748
# Processed transaction 49749
# Processed transaction 49750
# Processed transaction 49751
# Processed transaction 49752
# Processed transaction 49753
# Processed transaction 49754
# Processed transaction 49755
# Processed transaction 49756
# Processed transaction 49757
# Processed transaction 49758
# Processed transaction 49759
# Processed transaction 49760
# Processed transaction 49761
# Processed transaction 49762
# Processed transaction 49763
# Processed transaction 49764
# Processed transaction 49765
# Processed transaction 49766
# Processed transaction 49767
# Processed transaction 49768
# Processed transaction 49769
# Processed transaction 49770
# Processed transaction 49771
# Processed transaction 49772
# Processed transaction 49773
# Processed transaction 49774
# Processed transaction 49775
# Processed transaction 49776
# Processed transaction 49777
# Processed transaction 49778
# Processed transaction 49779
# Processed transaction 49780
# Processed transaction 49781
# Processed transaction 49782
# Processed transaction 49783
# Processed transaction 49784
# Processed transaction 49785
# Processed transaction 49786
# Processed transaction 49787
# Processed transaction 49788
# Processed transaction 49789
# Processed transaction 49790
# Processed transaction 49791
# Processed transaction 49792
# Processed transaction 49793
# Processed transaction 49794
# Processed transaction 49795
# Processed transaction 49796
# Processed transaction 49797
# Processed transaction 49798
# Processed transaction 49799
# Processed transaction 49800
# Processed transaction 49801
# Processed transaction 49802
# Processed transaction 49803
# Processed transaction 49804
# Processed transaction 49805
# Processed transaction 49806
# Processed transaction 49807
# Processed transaction 49808
# Processed transaction 49809
# Processed transaction 49810
# Processed transaction 49811
# Processed transaction 49812
# Processed transaction 49813
# Processed transaction 49814
# Processed transaction 49815
# Processed transaction 49816
# Processed transaction 49817
# Processed transaction 49818
# Processed transaction 49819
# Processed transaction 49820
# Processed transaction 49821
# Processed transaction 49822
# Processed transaction 49823
# Processed transaction 49824
# Processed transaction 49825
# Processed transaction 49826
# Processed transaction 49827
# Processed transaction 49828
# Processed transaction 49829
# Processed transaction 49830
# Processed transaction 49831
# Processed transaction 49832
# Processed transaction 49833
# Processed transaction 49834
# Processed transaction 49835
# Processed transaction 49836
# Processed transaction 49837
# Processed transaction 49838
# Processed transaction 49839
# Processed transaction 49840
# Processed transaction 49841
# Processed transaction 49842
# Processed transaction 49843
# Processed transaction 49844
# Processed transaction 49845
# Processed transaction 49846
# Processed transaction 49847
# Processed transaction 49848
# Processed transaction 49849
# Processed transaction 49850
# Processed transaction 49851
# Processed transaction 49852
# Processed transaction 49853
# Processed transaction 49854
# Processed transaction 49855
# Processed transaction 49856
# Processed transaction 49857
# Processed transaction 49858
# Processed transaction 49859
# Processed transaction 49860
# Processed transaction 49861
# Processed transaction 49862
# Processed transaction 49863
# Processed transaction 49864
# Processed transaction 49865
# Processed transaction 49866
# Processed transaction 49867
# Processed transaction 49868
# Processed transaction 49869
# Processed transaction 49870
# Processed transaction 49871
# Processed transaction 49872
# Processed transaction 49873
# Processed transaction 49874
# Processed transaction 49875
# Processed transaction 49876
# Processed transaction 49877
# Processed transaction 49878
# Processed transaction 49879
# Processed transaction 49880
# Processed transaction 49881
# Processed transaction 49882
# Processed transaction 49883
# Processed transaction 49884
# Processed transaction 49885
# Processed transaction 49886
# Processed transaction 49887
# Processed transaction 49888
# Processed transaction 49889
# Processed transaction 49890
# Processed transaction 49891
# Processed transaction 49892
# Processed transaction 49893
# Processed transaction 49894
# Processed transaction 49895
# Processed transaction 49896
# Processed transaction 49897
# Processed transaction 49898
# Processed transaction 49899
# Processed transaction 49900
# Processed transaction 49901
# Processed transaction 49902
# Processed transaction 49903
# Processed transaction 49904
# Processed transaction 49905
# Processed transaction 49906
# Processed transaction 49907
# Processed transaction 49908
# Processed transaction 49909
# Processed transaction 49910
# Processed transaction 49911
# Processed transaction 49912
# Processed transaction 49913
# Processed transaction 49914
# Processed transaction 49915
# Processed transaction 49916
# Processed transaction 49917
# Processed transaction 49918
# Processed transaction 49919
# Processed transaction 49920
# Processed transaction 49921
# Processed transaction 49922
# Processed transaction 49923
# Processed transaction 49924
# Processed transaction 49925
# Processed transaction 49926
# Processed transaction 49927
# Processed transaction 49928
# Processed transaction 49929
# Processed transaction 49930
# Processed transaction 49931
# Processed transaction 49932
# Processed transaction 49933
# Processed transaction 49934
# Processed transaction 49935
# Processed transaction 49936
# Processed transaction 49937
# Processed transaction 49938
# Processed transaction 49939
# Processed transaction 49940
# Processed transaction 49941
# Processed transaction 49942
# Processed transaction 49943
# Processed transaction 49944
# Processed transaction 49945
# Processed transaction 49946
# Processed transaction 49947
# Processed transaction 49948
# Processed transaction 49949
# Processed transaction 49950
# Processed transaction 49951
# Processed transaction 49952
# Processed transaction 49953
# Processed transaction 49954
# Processed transaction 49955
# Processed transaction 49956
# Processed transaction 49957
# Processed transaction 49958
# Processed transaction 49959
# Processed transaction 49960
# Processed transaction 49961
# Processed transaction 49962
# Processed transaction 49963
# Processed transaction 49964
# Processed transaction 49965
# Processed transaction 49966
# Processed transaction 49967
# Processed transaction 49968
# Processed transaction 49969
# Processed transaction 49970
# Processed transaction 49971
# Processed transaction 49972
# Processed transaction 49973
# Processed transaction 49974
# Processed transaction 49975
# Processed transaction 49976
# Processed transaction 49977
# Processed transaction 49978
# Processed transaction 49979
# Processed transaction 49980
# Processed transaction 49981
# Processed transaction 49982
# Processed transaction 49983
# Processed transaction 49984
# Processed transaction 49985
# Processed transaction 49986
# Processed transaction 49987
# Processed transaction 49988
# Processed transaction 49989
# Processed transaction 49990
# Processed transaction 49991
# Processed transaction 49992
# Processed transaction 49993
# Processed transaction 49994
# Processed transaction 49995
# Processed transaction 49996
# Processed transaction 49997
# Processed transaction 49998
# Processed transaction 49999
# ✅ Saved progress to /content/drive/MyDrive/colosseum_hackathon/datasets/pyusd_usdc_pool/pyusd_usdc_batch_9.csv
# Processed transaction 50000
# Processed transaction 50001
# Processed transaction 50002
# Processed transaction 50003
# Processed transaction 50004
# Processed transaction 50005
# Processed transaction 50006
# Processed transaction 50007
# Processed transaction 50008
# Processed transaction 50009
# Processed transaction 50010
# Processed transaction 50011
# Processed transaction 50012
# Processed transaction 50013
# Processed transaction 50014
# Processed transaction 50015
# Processed transaction 50016
# Processed transaction 50017
# Processed transaction 50018
# Processed transaction 50019
# Processed transaction 50020
# Processed transaction 50021
# Processed transaction 50022
# Processed transaction 50023
# Processed transaction 50024
# Processed transaction 50025
# Processed transaction 50026
# Processed transaction 50027
# Processed transaction 50028
# Processed transaction 50029
# Processed transaction 50030
# Processed transaction 50031
# Processed transaction 50032
# Processed transaction 50033
# Processed transaction 50034
# Processed transaction 50035
# Processed transaction 50036
# Processed transaction 50037
# Processed transaction 50038
# Processed transaction 50039
# Processed transaction 50040
# Processed transaction 50041
# Processed transaction 50042
# Processed transaction 50043
# Processed transaction 50044
# Processed transaction 50045
# Processed transaction 50046
# Processed transaction 50047
# Processed transaction 50048
# Processed transaction 50049
# Processed transaction 50050
# Processed transaction 50051
# Processed transaction 50052
# Processed transaction 50053
# Processed transaction 50054
# Processed transaction 50055
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2844151804.py in <cell line: 0>()
# ----> 1 txs_df = create_dataset_for_pool(
#       2     pool_address=WHIRLPOOL_ADDRESS,
#       3     token_mint_a="2b1kV6DkPAnxd5ixfnxCpjxmKwqjjaYmCZfHsFu24GXo",
#       4     token_mint_b="EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v",
#       5     token_vault_a="EeF6oBy6AQiBJoRx5xiRNxa6cmpQE3ayVagj28QFZuyg",
#
# /tmp/ipython-input-885661473.py in create_dataset_for_pool(pool_address, token_mint_a, token_mint_b, token_vault_a, token_vault_b, program_idl, lookback, before)
#      60     if pre_post_balances:
#      61       txs_df.loc[idx, 'pre_balance_a'] = float(pre_post_balances['pre_balance_a'])
# ---> 62       txs_df.loc[idx, 'pre_balance_b'] = float(pre_post_balances['pre_balance_b'])
#      63       txs_df.loc[idx, 'post_balance_a'] = float(pre_post_balances['post_balance_a'])
#      64       txs_df.loc[idx, 'post_balance_b'] = float(pre_post_balances['post_balance_b'])
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     909
#     910         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 911         iloc._setitem_with_indexer(indexer, value, self.name)
#     912
#     913     def _validate_key(self, key, axis: AxisInt):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1940         if take_split_path:
#    1941             # We have to operate column-wise
# -> 1942             self._setitem_with_indexer_split_path(indexer, value, name)
#    1943         else:
#    1944             self._setitem_single_block(indexer, value, name)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _setitem_with_indexer_split_path(self, indexer, value, name)
#    2033             # scalar value
#    2034             for loc in ilocs:
# -> 2035                 self._setitem_single_column(loc, value, pi)
#    2036
#    2037     def _setitem_with_indexer_2d_value(self, indexer, value):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _setitem_single_column(self, loc, value, plane_indexer)
#    2173                     value, len(self.obj)
#    2174                 )
# -> 2175             self.obj._mgr.column_setitem(loc, plane_indexer, value)
#    2176
#    2177         self.obj._clear_item_cache()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in column_setitem(self, loc, idx, value, inplace_only)
#    1335             col_mgr.setitem_inplace(idx, value)
#    1336         else:
# -> 1337             new_mgr = col_mgr.setitem((idx,), value)
#    1338             self.iset(loc, new_mgr._block.values, inplace=True)
#    1339
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in setitem(self, indexer, value, warn)
#     413             self = self.copy()
#     414
# --> 415         return self.apply("setitem", indexer=indexer, value=value)
#     416
#     417     def diff(self, n: int) -> Self:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, **kwargs)
#     361                 applied = b.apply(f, **kwargs)
#     362             else:
# --> 363                 applied = getattr(b, f)(**kwargs)
#     364             result_blocks = extend_blocks(applied, result_blocks)
#     365
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/blocks.py in setitem(self, indexer, value, using_cow)
#    1371     # ---------------------------------------------------------------------
#    1372
# -> 1373     def setitem(self, indexer, value, using_cow: bool = False) -> Block:
#    1374         """
#    1375         Attempt self.values[indexer] = value, possibly creating a new array.
#
# KeyboardInterrupt:

# %%
txs_df['token_amount_a_ui'] = txs_df['token_amount_a'] / 10 ** txs_df['decimals_a']
txs_df['token_amount_b_ui'] = txs_df['token_amount_b'] / 10 ** txs_df['decimals_b']

# %%
txs_df.to_csv("/content/drive/MyDrive/colosseum_hackathon/datasets/sol_pengu_pool/sol_pengu_part3.csv", index=False)

# %%
txs_df.head()
# Out:
#         slot  block_time                                       tx_signature  \
# 0  372557788  1760144646  5PtvLMtwReCWfLcLp9V2NKUGvgYdRCN3qaUuUW6NMv3iMY...
# 1  372557787  1760144646  4urJ6EyerDrf7KxWcLg9sGggd87BPhDZFs6GzAWiBceDdk...
# 2  372557786  1760144645  2bvpAkVjNEZr37brggYbo7cyHUTHiag69kjiLF6hAeKhZo...
# 3  372557785  1760144645  5pRxua1qbLCczQbt7Cq2srNTUW1ZcDztRoRyqWDREsceNu...
# 4  372557784  1760144645  4YzyHDMxPztgVteM7Vg1F2bJMkRFqndVgCg6JN6Rjufzkx...
#
#                                   token_mint_a  \
# 0  So11111111111111111111111111111111111111112
# 1  So11111111111111111111111111111111111111112
# 2  So11111111111111111111111111111111111111112
# 3  So11111111111111111111111111111111111111112
# 4  So11111111111111111111111111111111111111112
#
#                                    token_mint_b  \
# 0  2zMMhcVQEXDtdE6vsFS7S7D5oUodfJHE8vd1gnBouauv
# 1  2zMMhcVQEXDtdE6vsFS7S7D5oUodfJHE8vd1gnBouauv
# 2  2zMMhcVQEXDtdE6vsFS7S7D5oUodfJHE8vd1gnBouauv
# 3  2zMMhcVQEXDtdE6vsFS7S7D5oUodfJHE8vd1gnBouauv
# 4  2zMMhcVQEXDtdE6vsFS7S7D5oUodfJHE8vd1gnBouauv
#
#                                   token_vault_a  \
# 0  J757hq9DXGPDYfCoeGpTcD9A71NFgNqBRMXHrdVGyRxK
# 1  J757hq9DXGPDYfCoeGpTcD9A71NFgNqBRMXHrdVGyRxK
# 2  J757hq9DXGPDYfCoeGpTcD9A71NFgNqBRMXHrdVGyRxK
# 3  J757hq9DXGPDYfCoeGpTcD9A71NFgNqBRMXHrdVGyRxK
# 4  J757hq9DXGPDYfCoeGpTcD9A71NFgNqBRMXHrdVGyRxK
#
#                                  token_vault_b  num_swaps  token_amount_a  \
# 0  SdFLxX6sWTkKWje3Xb4YNewbm5ieaj3tfEJYeLTyqyg          1      1150004045
# 1  SdFLxX6sWTkKWje3Xb4YNewbm5ieaj3tfEJYeLTyqyg          1      8714974177
# 2  SdFLxX6sWTkKWje3Xb4YNewbm5ieaj3tfEJYeLTyqyg          1     17824102794
# 3  SdFLxX6sWTkKWje3Xb4YNewbm5ieaj3tfEJYeLTyqyg          1      3500612153
# 4  SdFLxX6sWTkKWje3Xb4YNewbm5ieaj3tfEJYeLTyqyg          1       390086808
#
#    token_amount_b  pre_balance_a  pre_balance_b  post_balance_a  \
# 0      8903724052   14939.956068   1.836553e+08    14938.806064
# 1     67447466742   14948.671042   1.835879e+08    14939.956068
# 2    137797887740   14966.495145   1.834501e+08    14948.671042
# 3     27039937359   14969.995757   1.834231e+08    14966.495145
# 4      3012693565   14970.385844   1.834200e+08    14969.995757
#
#    post_balance_b  decimals_a  decimals_b
# 0    1.836642e+08           9           6
# 1    1.836553e+08           9           6
# 2    1.835879e+08           9           6
# 3    1.834501e+08           9           6
# 4    1.834231e+08           9           6
